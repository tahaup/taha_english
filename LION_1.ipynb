# %% [markdown]
# ### if

# %%
x = 10
x
# Out:
# 10

# %%
x = "I have 10 Toman"
x
# Out:
# 'I have 10 Toman'

# %%
x
# Out:
# 'I have 10 Toman'

# %%
if x == 10 :
    print("x is 10")

# %%
N = 5

# %%
if N == 5 :
    print("5")

# %%
N = 3
N
# Out:
# 3

# %%
if N == 5 :
    print("It's Five")
elif N == 6 :
    print("It's six")
elif N == 9 :
    print("It's nine")
else:
    print("Agha velam kon nist dege. ey baba. seerish!!!!!")
# Out:
# Agha velam kon nist dege. ey baba. seerish!!!!!

# %%
x = input()
# Out:
#   lllllllllllhhhhhhhhhhhhhhhhhhhhhhhhffffffffffaaaaaaaaaaaaaaaaabbaaababababaaabaababaaabababmsmznsjjhjhjhjhjhjjjjjllklklklllhlhhllhllllljjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjj;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;jjjjjjjjjjjjjjjjjjjjjjjjjjjjjuuuuuuuuuuuuuuuuuuuuuugggggggggggggggggggggggggggggggggggggggddddddssssssswwweaaaaaaaefffffffffffffrrrrrrrr555555555555555555555555bbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbiiiinl kli lnuiuygtfrfvy ryr         y ...,ND,NFNGBJ,JNG,JN,NBK,CMCGKMKMD      7UDHRHKFDHKUG========+++++FKHYUBVHUXHBCFGYHDFYGFVYTGBGBNYRTGJRTGJMRJGYUTJRTH,TUTJHTJHJKNHKGNKFGJHKHJGHIHKTH,NJGK,HKGIHMKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKK
# ...

# %%
x
# Out:
# 'hfhfhhfghfgh'

# %%
x ="Rediceles boy" *200000

# %%
x
# Out:
# 'Rediceles boyRediceles boyRediceles boyRediceles boyRediceles boyRediceles boyRediceles boyRediceles boyRediceles boyRediceles boyRediceles boyRediceles boyRediceles boyRediceles boyRediceles boyRediceles boyRediceles boyRediceles boyRediceles boyRediceles boyRediceles boyRediceles boyRediceles boyRediceles boyRediceles boyRediceles boyRediceles boyRediceles boyRediceles boyRediceles boyRediceles boyRediceles boyRediceles boyRediceles boyRediceles boyRediceles boyRediceles boyRediceles boyRediceles boyRediceles boyRediceles boyRediceles boyRediceles boyRediceles boyRediceles boyRediceles boyRediceles boyRediceles boyRediceles boyRediceles boyRediceles boyRediceles boyRediceles boyRediceles boyRediceles boyRediceles boyRediceles boyRediceles boyRediceles boyRediceles boyRediceles boyRediceles boyRediceles boyRediceles boyRediceles boyRediceles boyRediceles boyRediceles boyRediceles boyRediceles boyRediceles boyRediceles boyRediceles boyRediceles boyRediceles boyRediceles boyRediceles
# ...

# %% [markdown]
# ### I work "if", "input" and "imoji"

# %%
B = 5

# %%
if B == 3 : 
    print("five")
elif B == 5 :
    print("good")
# Out:
# good

# %%
p = 7

# %%
if p == 6 :
    print("goodjod")
elif p == 7 :
    print("good")
# Out:
# good

# %%
print("fox")
# Out:
# fox

# %%
print("123456789"*2000)
# Out:
# ...

# %%
j = int(j)
# Out:
#  6

# %%
LL = int(input())
# Out:
#  5

# %%
LL * j
# Out:
# 30

# %%
5 * 6
# Out:
# 30

# %%
b = 7

# %%
b = int(input())
# Out:
#  1

# %%
print(chr(0x1f602))
# Out:
# 😂

# %%
print(chr(0x1f606))
# Out:
# 😆

# %%
print(chr(0x1f308))
# Out:
# 🌈

# %%
print(chr(0x1f197))
# Out:
# 🆗

# %% [markdown]
# ### play

# %%
# play name
# vocab game
# write this game with python
