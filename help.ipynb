# %% [markdown]
# ### help

# %%
print("blak")
# Out:
# blak

# %%
# powershell

# %%
# f:

# %%
# cd ch

# %%
# .\venv\Scripts\activate

# %%
# powershell
# f:
# cd ch
# .\venv\Scripts\activate

# %%
 # !python ch.py 5
# Out:
# ##############################################
# ############# Speaking Textbook ##############
# ##############################################
# 221: How many pillows?
# 21: Excuse me teacher!
# 111: Your wellcome!
# 48: Put away your books.
# 45: Speak more slowly.
# 58: Whats your phone number?
# 204: Copy the word.
# 215: Do you like rice?
# 292: Can I talk you, please?
# 245: What's the opposite of happy?
# ##############################################
# Asked: 40
# ##############################################

# %%
9*9
# Out:
# 81

# %%
print("orang"*9)
# Out:
# orangorangorangorangorangorangorangorangorang

# %%
v = 22

# %%
g =22

# %%
v
# Out:
# 22

# %%
g
# Out:
# 22

# %%
g + v
# Out:
# 44

# %%
g - v
# Out:
# 0

# %%
a = {"taha": "10", "baba": "40", "mahta": "4", "maman": "35"}

# %%
a
# Out:
# {'taha': '10', 'baba': '40', 'mahta': '4', 'maman': '35'}

# %%
w = {"loo": "10"}

# %%
w
# Out:
# {'loo': '10'}

# %%
print("family"*333)
# Out:
# ...

# %%
print("family   "*888)
# Out:
# family   family   family   family   family   family   family   family   family   family   family   family   family   family   family   family   family   family   family   family   family   family   family   family   family   family   family   family   family   family   family   family   family   family   family   family   family   family   family   family   family   family   family   family   family   family   family   family   family   family   family   family   family   family   family   family   family   family   family   family   family   family   family   family   family   family   family   family   family   family   family   family   family   family   family   family   family   family   family   family   family   family   family   family   family   family   family   family   family   family   family   family   family   family   family   family   family   family   family   family   family   family   family   family   family   family   family   family   family   family   family  
# ...

# %%
I love you my dad,mom,grandma,grandpa,ant and uncle from:taha....

# %%
![Alt text](.\taha.png)

This is here.

# %%
school
noise

# %%
# ncpa.cpl

# %% [markdown]
# m=12

# %%
m
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 m
#
# NameError: name 'm' is not defined

# %%
v = 12

# %%
v
# Out:
# 12

# %%
print("mohammad and taha"*2000)
# Out:
# mohammad and tahamohammad and tahamohammad and tahamohammad and tahamohammad and tahamohammad and tahamohammad and tahamohammad and tahamohammad and tahamohammad and tahamohammad and tahamohammad and tahamohammad and tahamohammad and tahamohammad and tahamohammad and tahamohammad and tahamohammad and tahamohammad and tahamohammad and tahamohammad and tahamohammad and tahamohammad and tahamohammad and tahamohammad and tahamohammad and tahamohammad and tahamohammad and tahamohammad and tahamohammad and tahamohammad and tahamohammad and tahamohammad and tahamohammad and tahamohammad and tahamohammad and tahamohammad and tahamohammad and tahamohammad and tahamohammad and tahamohammad and tahamohammad and tahamohammad and tahamohammad and tahamohammad and tahamohammad and tahamohammad and tahamohammad and tahamohammad and tahamohammad and tahamohammad and tahamohammad and tahamohammad and tahamohammad and tahamohammad and tahamohammad and tahamohammad and tahamohammad and tahamohammad and
# ...

# %%
print("mohamad and taha"*2500)
# Out:
# mohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohama
# ...

# %%
print("mohamad and taha"*3000)
# Out:
# mohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohamad and tahamohama
# ...

# %%
print("yellow"*4000)
# Out:
# ...

# %%
print("orange"*5000)
# Out:
# ...

# %%
print("o my god"*2)
# Out:
# o my godo my god
